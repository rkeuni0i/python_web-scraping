# %%
import requests
import lxml
import bs4
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
plt.rcParams['font.family'] = 'malgun gothic'
utl = "http://naver.com"
headers={"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/136.0.0.0 Safari/537.36"}
res = requests.get(utl, headers = headers)
print(res.status_code)
# Out:
# 200

# %%
res.raise_for_status()
print("웹 스크래핑이 성공적으로 작동됩니다.")
# Out:
# 웹 스크래핑이 성공적으로 작동됩니다.

# %%
print(res.text)
# Out:
#    <!doctype html> <html lang="ko" class="fzoom"> <head> <meta charset="utf-8"> <meta name="Referrer" content="origin"> <meta http-equiv="X-UA-Compatible" content="IE=edge"> <meta name="viewport" content="width=1190"> <title>NAVER</title> <meta name="apple-mobile-web-app-title" content="NAVER"/> <meta name="robots" content="index,nofollow"/> <meta name="description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta property="og:title" content="네이버"> <meta property="og:url" content="https://www.naver.com/"> <meta property="og:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta property="og:description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta name="twitter:card" content="summary"> <meta name="twitter:title" content=""> <meta name="twitter:url" content="https://www.naver.com/"> <meta name="twitter:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta name="twitter:description"
# ...

# %%
with open("naverdoc.html", "w", encoding="utf-8") as f:
    f.write(res.text)

# %%
import requests 
import lxml.html
from bs4 import BeautifulSoup as bs
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
plt.rcParams['font.family'] = 'malgun gothic'
utl = "https://comic.naver.com/index"
res = requests.get(utl)
res.raise_for_status()
soup = bs(res.text, "html.parser")
print(soup.title)
print(soup.body.div.a)
print(soup.body)
# Out:
# <title>네이버 웹툰</title>
# None
# <body>
# <div id="root"></div>
# </body>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[45], line 17
#      15 print(soup.body.div.a)
#      16 print(soup.body)
# ---> 17 print(soup.a["href"])
#
# TypeError: 'NoneType' object is not subscriptable

# %%
import requests 
import lxml.html
from bs4 import BeautifulSoup as bs
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
plt.rcParams['font.family'] = 'malgun gothic'
stock_url = "https://finance.naver.com//item/sise_day.naver?code=005930"
headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/136.0.0.0 Safari/537.36"}
requests.get(stock_url, headers = headers)
res = requests.get(stock_url, headers = headers)
soup = bs(res.text, 'html.parser')
parsing_list = soup.find_all("tr")
isCheckNone = None
for i in range(1, len(parsing_list)):
    if(parsing_list[i].span != isCheckNone):
        print(parsing_list[i].find_all("td", align="center")[0].text, parsing_list[i].find_All("td", calss_="num")[0].text)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[49], line 19
#      17 for i in range(1, len(parsing_list)):
#      18     if(parsing_list[i].span != isCheckNone):
# ---> 19         print(parsing_list[i].find_all("td", align="center")[0].text, parsing_list[i].find_All("td", calss_="num")[0].text)
#
# TypeError: 'NoneType' object is not callable

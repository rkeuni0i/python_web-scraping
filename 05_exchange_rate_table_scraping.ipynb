# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from datetime import datetime

df = pd.DataFrame()
for page in range(1,2) :
    url = 'https://finance.naver.com/marketindex/exchangeList.naver'
    headers = {"User-Agent" : "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/136.0.0.0 Safari/537.36"}
    res = requests.get(url,headers = headers)

    new_data = pd.read_html(res.text,header=0,skiprows=1)[0]
    df = pd.concat([df, new_data], ignore_index=True)

df=df.dropna()
df = df.head(10)
df = df.rename(columns={'통화명': '국가명', '매매기준율': '환율'})
df = df[['국가명', '환율']]
df
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_35564\3493965514.py:12: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   new_data = pd.read_html(res.text,header=0,skiprows=1)[0]
#               국가명       환율
# 0          미국 USD  1395.50
# 1        유럽연합 EUR  1569.66
# 2   일본 JPY (100엔)   965.34
# 3          중국 CNY   193.27
# 4          홍콩 HKD   178.27
# 6          영국 GBP  1864.88
# 8         캐나다 CAD  1000.97
# 9         스위스 CHF  1674.06
# 10        스웨덴 SEK   144.29
# 11         호주 AUD   895.21
